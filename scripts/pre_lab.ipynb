# %%
import pystac_client
import stackstac
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✓ pystac_client:", pystac_client.__version__)
print("✓ stackstac version OK")
print("✓ sklearn:", sklearn.__version__)
print("✓ All core dependencies loaded successfully")
# Out:
# ✓ pystac_client: 0.9.0
# ✓ stackstac version OK
# ✓ sklearn: 1.8.0
# ✓ All core dependencies loaded successfully

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
print("✓ scikit-learn metrics ready for Week 9")
# Out:
# ✓ scikit-learn metrics ready for Week 9

# %%
PRE_ITEM_IDS = "S2A_MSIL2A_20250615T023141_R046_T51QUG_20250615T070417"
PRE_ITEM_ID = "S2C_MSIL2A_20250911T022551_R046_T51QUG_20250911T055914"
POST_ITEM_ID = "S2B_MSIL2A_20251016T022559_R046_T51QUG_20251016T042804"
